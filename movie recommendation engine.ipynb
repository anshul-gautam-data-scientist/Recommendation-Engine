# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_5228\2089594497.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies_metadata.csv')

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
for i in df:
    print(i)
# Out:
# adult
# belongs_to_collection
# budget
# genres
# homepage
# id
# imdb_id
# original_language
# original_title
# overview
# popularity
# poster_path
# production_companies
# production_countries
# release_date
# revenue
# runtime
# spoken_languages
# status
# tagline
# title
# video
# vote_average
# vote_count

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
df['original_language'].value_counts()
# Out:
# en       32269
# fr        2438
# it        1529
# ja        1350
# de        1080
#          ...
# zu           1
# qu           1
# 104.0        1
# la           1
# si           1
# Name: original_language, Length: 92, dtype: int64

# %%
df['original_language'].value_counts()[0:5]
# Out:
# en    32269
# fr     2438
# it     1529
# ja     1350
# de     1080
# Name: original_language, dtype: int64

# %%
plt.figure(figsize = (5,5))

# %%
plt.bar(list(df['original_language'].value_counts()[0:6].keys()), list (df['original_language'].value_counts()[0:6]), color = 'r')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize=(5,5))
plt.hist(df['vote_average'])
plt.show()

# %%
high_rated_movies = df[df['vote_average']>8]
high_rated_movies.head()
# Out:
#      adult                              belongs_to_collection    budget  \
# 46   False                                                NaN  33000000
# 49   False                                                NaN   6000000
# 109  False                                                NaN   1300000
# 186  False                                                NaN         0
# 256  False  {'id': 10, 'name': 'Star Wars Collection', 'po...  11000000
#
#                                                 genres  \
# 46   [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 49   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 109  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 186  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 256  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                               homepage     id    imdb_id  \
# 46                          http://www.sevenmovie.com/    807  tt0114369
# ...

# %%
high_rated_movies.shape
# Out:
# (1130, 24)

# %%
top5_high = high_rated_movies.sort_values(by='vote_average',ascending = False).head()

# %%
top5_high
# Out:
#        adult belongs_to_collection budget  \
# 42628  False                   NaN      0
# 42477  False                   NaN      0
# 32873  False                   NaN      0
# 11050  False                   NaN      0
# 32797  False                   NaN      0
#
#                                                   genres  \
# 42628                     [{'id': 35, 'name': 'Comedy'}]
# 42477  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 32873                    [{'id': 36, 'name': 'History'}]
# 11050  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 32797  [{'id': 35, 'name': 'Comedy'}, {'id': 878, 'na...
#
#                                                 homepage      id    imdb_id  \
# 42628  http://www.sho.com/titles/3432660/Sebastian%20...  415735  tt6295304
# 42477               http://www.imdb.com/title/tt3889450/  343018  tt3889450
# 32873                                                NaN  218974  tt3123116
# ...
